# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))
from wanna_buy_house.data import *
from wanna_buy_house import utils
import joblib
import pandas as pd

# %%
os.path
os.getcwd()
os.path.join(os.getcwd(), '..')
os.path.dirname(os.getcwd())
# Out:
# '/Users/sanderiwase/code/sanderiw/project493'

# %%
sys.path
# Out:
# ['/Users/sanderiwase/code/sanderiw/project493/notebooks',
#  '/Users/sanderiwase/code/sanderiw/data-challenges/04-Decision-Science',
#  '/Users/sanderiwase/code/sanderiw/project493/notebooks',
#  '/Users/sanderiwase/.pyenv/versions/3.7.7/Python.framework/Versions/3.7/lib/python37.zip',
#  '/Users/sanderiwase/.pyenv/versions/3.7.7/Python.framework/Versions/3.7/lib/python3.7',
#  '/Users/sanderiwase/.pyenv/versions/3.7.7/lib/python3.7/lib-dynload',
#  '',
#  '/Users/sanderiwase/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages',
#  '/Users/sanderiwase/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/sanderiwase/.ipython',
#  '/Users/sanderiwase/code/sanderiw/project493']

# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))
from wanna_buy_house import data
from wanna_buy_house import utils
data = data.final_treatment()
# Out:
# get_data 0.37

# %%
data
# Out:
#        Current.Loan.Amount        Term Home.Ownership  Annual.Income  \
# 0                    17879  Short Term  Home Mortgage        95357.0
# 3                    11200  Short Term           Rent        53965.0
# 4                     3608  Short Term  Home Mortgage        47709.0
# 5                     7877  Short Term  Home Mortgage        47707.0
# 6                     4732   Long Term           Rent        62721.0
# ...                    ...         ...            ...            ...
# 60794                14885  Short Term           Rent       124875.0
# 60795                 5086  Short Term  Home Mortgage        50855.0
# 60797                27840   Long Term  Home Mortgage        99430.0
# 60800                18229  Short Term           Rent        91143.0
# 60803                 2866  Short Term  Home Mortgage        42991.0
#
#        Current.Credit.Balance  Loan.Status Number.of.Open.Accounts.Buckets  \
# ...

# %%
pipeline = joblib.load('../model.joblib')

# %%
input_teste = pd.DataFrame({'Loan.ID': [0],
						 'Current.Loan.Amount': [17879],
						 'Term': ['Short Term'],
						 'Credit.Score': [739.0],
						 'Years.in.current.job': ['6 years'],
						 'Home.Ownership': ['Home Mortgage'],
						 'Annual.Income': [95357.0],
						 'Purpose': ['Debt Consolidation'],
						 'Monthly.Debt': [1509.82],
						 'Years.of.Credit.History': [34.4],
						 'Months.since.last.delinquent': [5.0],
						 'Number.of.Open.Accounts': [26],
						 'Number.of.Credit.Problems': [0],
						 'Current.Credit.Balance': [23986],
						 'Maximum.Open.Credit': [40313],
						 'Bankruptcies': [0.0],
						 'Tax.Liens': [0.0]})

# %%
input_teste
# Out:
#    Loan.ID  Current.Loan.Amount        Term  Credit.Score  \
# 0        0                17879  Short Term         739.0
#
#   Years.in.current.job Home.Ownership  Annual.Income             Purpose  \
# 0              6 years  Home Mortgage        95357.0  Debt Consolidation
#
#    Monthly.Debt  Years.of.Credit.History  Months.since.last.delinquent  \
# 0       1509.82                     34.4                           5.0
#
#    Number.of.Open.Accounts  Number.of.Credit.Problems  Current.Credit.Balance  \
# 0                       26                          0                   23986
#
#    Maximum.Open.Credit  Bankruptcies  Tax.Liens
# 0                40313           0.0        0.0

# %%
xx = pipeline.predict_proba(data.head(100))
# Out:
# /Users/sanderiwase/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)

# %%
data = get_data()
data = clean_data(data)
data.head(50)
# Out:
# get_data 0.36
#     Loan.ID  Current.Loan.Amount        Term  Credit.Score  \
# 0         0                17879  Short Term         739.0
# 3         4                11200  Short Term         738.0
# 4         5                 3608  Short Term         731.0
# 5         7                 7877  Short Term         738.0
# 6         8                 4732   Long Term         701.0
# 7        10                 3469  Short Term         735.0
# 8        11                10031  Short Term         712.0
# 10       15                20044  Short Term         741.0
# 13       18                 4836  Short Term         723.0
# 14       19                 6162  Short Term         684.0
# 15       21                15538  Short Term         709.0
# 16       22                 5917  Short Term         745.0
# 17       23                 5066  Short Term         745.0
# 18       25                32596   Long Term         739.0
# 19       26                 5409  Short Term         744.0
# ...

# %%
data1 = pd.DataFrame(xx)
data1['true'] = x

# %%
data1.head(60)
# Out:
#            0         1  true
# 0   0.060000  0.940000     1
# 1   0.400000  0.600000     1
# 2   0.031304  0.968696     1
# 3   0.220000  0.780000     1
# 4   0.380000  0.620000     0
# 5   0.929474  0.070526     0
# 6   0.360000  0.640000     1
# 7   0.340000  0.660000     1
# 8   0.271304  0.728696     1
# 9   0.900000  0.100000     0
# 10  0.100000  0.900000     1
# 11  0.728810  0.271190     0
# 12  0.080000  0.920000     1
# 13  0.300000  0.700000     1
# 14  0.020000  0.980000     1
# 15  0.220000  0.780000     1
# 16  0.200000  0.800000     1
# 17  0.300000  0.700000     1
# 18  0.230000  0.770000     1
# 19  0.100000  0.900000     1
# 20  0.060000  0.940000     1
# 21  0.057030  0.942970     1
# 22  0.960000  0.040000     0
# 23  0.160000  0.840000     1
# 24  0.140000  0.860000     1
# 25  0.180000  0.820000     1
# 26  0.840000  0.160000     0
# 27  0.020000  0.980000     1
# 28  0.180000  0.820000     1
# 29  0.240000  0.760000     1
# 30  0.331000  0.669000     1
# ...

# %%
x = data.head(100)['Loan.Status'].reset_index().drop(columns='index')

# %%
x
# Out:
#     Loan.Status
# 0             1
# 1             1
# 2             1
# 3             1
# 4             0
# ..          ...
# 95            0
# 96            1
# 97            0
# 98            1
# 99            1
#
# [100 rows x 1 columns]
