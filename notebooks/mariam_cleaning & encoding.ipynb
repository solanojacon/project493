# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_original = pd.read_csv('raw_data/train.csv')
data_original.head(5)
# Out:
#    Loan.ID  Current.Loan.Amount        Term  Credit.Score  \
# 0        0                17879  Short Term         739.0
# 1        1             99999999   Long Term         619.0
# 2        3             99999999  Short Term         738.0
# 3        4                11200  Short Term         738.0
# 4        5                 3608  Short Term         731.0
#
#   Years.in.current.job Home.Ownership  Annual.Income             Purpose  \
# 0              6 years  Home Mortgage        95357.0  Debt Consolidation
# 1              6 years           Rent        54406.0  Debt Consolidation
# 2    less than  1 year           Rent        40480.0       Medical Bills
# 3              4 years           Rent        53965.0  Debt Consolidation
# 4            10+ years  Home Mortgage        47709.0   Home Improvements
#
#    Monthly.Debt  Years.of.Credit.History  Months.since.last.delinquent  \
# 0       1509.82                     34.4                           5.0
# 1       1065.45                     12.7                           NaN
# 2        573.47                     32.7                          60.0
# 3       1358.11                     15.8                           NaN
# 4        339.93                     16.1                          47.0
#
#    Number.of.Open.Accounts  Number.of.Credit.Problems  Current.Credit.Balance  \
# 0                       26                          0                   23986
# 1                        8                          0                   22938
# 2                        9                          1                    3963
# 3                        8                          1                   11782
# 4                        6                          0                   22909
#
#    Maximum.Open.Credit  Bankruptcies  Tax.Liens  Loan.Status
# 0                40313           0.0        0.0            1
# 1                31250           0.0        0.0            1
# 2                 5669           1.0        0.0            1
# 3                25951           1.0        0.0            1
# 4                25568           0.0        0.0            1

# %% [markdown]
# ## 1. CLEANING

# %%
# (1) Deleting rows with Current.Loan.Amount equal to 99999999
data = data_original[data_original['Current.Loan.Amount'] != 99999999].copy()

# %%
# (2) Deleting rows where Credit.Score and Annual.Income are NA
data = data[data['Credit.Score'].notna()]
data = data[data['Annual.Income'].notna()]

# %%
# (3) Na coluna Home.Ownership, HaveMortgage substituido por Home Mortgage
data['Home.Ownership'] = data['Home.Ownership'].replace(['HaveMortgage'], 'Home Mortgage')

# %%
# (4) If Years.in.current.job is null, fill out with "less than 1 year"
data['Years.in.current.job'] = data['Years.in.current.job'].fillna('less than 1 year')
data['Years.in.current.job'] = data['Years.in.current.job'].replace(['less than  1 year'], 'less than 1 year')

# %%
# (5) If Bankruptcies are null, substitute by 0
data['Bankruptcies'] = data['Bankruptcies'].fillna(0)

# %%
# (6) If Tax.Liens are null, substitute by 0
data['Tax.Liens'] = data['Tax.Liens'].fillna(0)

# %%
# (7) If Credit.Score > 850 (maximum), divive by 10 (assuming there was a typing error)
#(e.g., instead of typing 750, person typed 7500)

def div(x):
    if x > 850:
        return x / 10
    else:
        return x

data['Credit.Score'] = data['Credit.Score'].apply(div)

# %% [markdown]
# ## 2. ENCODING

# %%
#(1) Number of open accounts: buckets (0-10, 11-20, mais de 20)
data['Number.of.Open.Accounts.Buckets'] = data['Number.of.Open.Accounts']

def encoding_noab(x):
    if x < 10:
        return '0-10'
    elif x > 20:
        return 'mais de 20'
    else:
        return '11-20'

data['Number.of.Open.Accounts.Buckets'] = data['Number.of.Open.Accounts.Buckets'].apply(encoding_noab)
data.drop(columns='Number.of.Open.Accounts')
# Out:
#        Loan.ID  Current.Loan.Amount        Term  Credit.Score  \
# 0            0                17879  Short Term         739.0
# 3            4                11200  Short Term         738.0
# 4            5                 3608  Short Term         731.0
# 5            7                 7877  Short Term         738.0
# 6            8                 4732   Long Term         701.0
# 7           10                 3469  Short Term         735.0
# 8           11                10031  Short Term         712.0
# 10          15                20044  Short Term         741.0
# 13          18                 4836  Short Term         723.0
# 14          19                 6162  Short Term         684.0
# 15          21                15538  Short Term         709.0
# 16          22                 5917  Short Term         745.0
# 17          23                 5066  Short Term         745.0
# 18          25                32596   Long Term         739.0
# 19          26                 5409  Short Term         744.0
# 20          28                18295   Long Term         692.0
# 22          31                 4970  Short Term         707.0
# 23          33                 2412  Short Term         739.0
# 24          34                25245   Long Term         711.0
# 25          35                 4895  Short Term         673.0
# 28          39                 9758  Short Term         659.0
# 29          40                14918  Short Term         744.0
# 30          41                11588   Long Term         718.0
# 31          43                23942  Short Term         718.0
# 32          44                 8158  Short Term         732.0
# 34          47                11732  Short Term         743.0
# 35          49                30078   Long Term         695.0
# 36          51                 4898  Short Term         722.0
# 37          52                 6820  Short Term         722.0
# 39          54                 4965  Short Term         743.0
# ...        ...                  ...         ...           ...
# 60754    84121                25436  Short Term         746.0
# 60755    84122                 3572  Short Term         706.0
# 60756    84124                14751   Long Term         740.0
# 60759    84129                14795   Long Term         655.0
# 60760    84130                13718  Short Term         726.0
# 60761    84131                12020  Short Term         740.0
# 60762    84132                 7974  Short Term         716.0
# 60763    84133                 6537  Short Term         664.0
# 60765    84136                12101  Short Term         716.0
# 60766    84137                 5416  Short Term         730.0
# 60768    84140                 8784  Short Term         717.0
# 60769    84142                15915  Short Term         744.0
# 60774    84149                12730  Short Term         744.0
# 60776    84151                 6185   Long Term         651.0
# 60778    84154                 3877  Short Term         729.0
# 60779    84155                 4554  Short Term         712.0
# 60780    84157                 5007  Short Term         713.0
# 60781    84158                30255  Short Term         720.0
# 60782    84160                 9865  Short Term         715.0
# 60783    84161                22499   Long Term         648.0
# 60784    84163                 9957  Short Term         723.0
# 60787    84167                 9666  Short Term         736.0
# 60788    84168                 9882  Short Term         701.0
# 60789    84169                14749  Short Term         694.0
# 60793    84175                20268  Short Term         746.0
# 60794    84176                14885  Short Term         723.0
# 60795    84178                 5086  Short Term         723.0
# 60797    84181                27840   Long Term         597.0
# 60800    84185                18229  Short Term         747.0
# 60803    84189                 2866  Short Term         703.0
#
#       Years.in.current.job Home.Ownership  Annual.Income             Purpose  \
# 0                  6 years  Home Mortgage        95357.0  Debt Consolidation
# 3                  4 years           Rent        53965.0  Debt Consolidation
# 4                10+ years  Home Mortgage        47709.0   Home Improvements
# 5                  5 years  Home Mortgage        47707.0   Home Improvements
# 6                10+ years           Rent        62721.0               other
# 7                  5 years           Rent        25135.0  Debt Consolidation
# 8                  6 years           Rent       150465.0               other
# 10                 3 years  Home Mortgage        91200.0  Debt Consolidation
# 13               10+ years  Home Mortgage        75563.0  Debt Consolidation
# 14               10+ years  Home Mortgage        74154.0  Debt Consolidation
# 15                 6 years  Home Mortgage        87479.0  Debt Consolidation
# 16                 6 years  Home Mortgage        69034.0       Business Loan
# 17                 3 years  Home Mortgage        75983.0  Debt Consolidation
# 18                  1 year  Home Mortgage       175680.0   Home Improvements
# 19                 4 years           Rent       140641.0              moving
# 20               10+ years  Home Mortgage        51836.0  Debt Consolidation
# 22        less than 1 year           Rent        34790.0  Debt Consolidation
# 23                 8 years           Rent        25630.0  Debt Consolidation
# 24                 5 years  Home Mortgage        68666.0  Debt Consolidation
# 25                 4 years           Rent        24473.0  Debt Consolidation
# 28                 2 years           Rent       107338.0       Business Loan
# 29               10+ years  Home Mortgage        61659.0  Debt Consolidation
# 30                 5 years  Home Mortgage        63745.0  Debt Consolidation
# 31               10+ years  Home Mortgage        84796.0  Debt Consolidation
# 32               10+ years           Rent        61188.0  Debt Consolidation
# 34        less than 1 year  Home Mortgage        53774.0  Debt Consolidation
# 35               10+ years  Home Mortgage       148385.0  Debt Consolidation
# 36        less than 1 year  Home Mortgage       117346.0  Debt Consolidation
# 37                 8 years  Home Mortgage        34476.0  Debt Consolidation
# 39               10+ years  Home Mortgage       115188.0  Debt Consolidation
# ...                    ...            ...            ...                 ...
# 60754            10+ years  Home Mortgage        69459.0  Debt Consolidation
# 60755            10+ years  Home Mortgage        53573.0               other
# 60756              7 years  Home Mortgage        78672.0  Debt Consolidation
# 60759            10+ years  Home Mortgage       212055.0  Debt Consolidation
# 60760              9 years  Home Mortgage        39056.0  Debt Consolidation
# 60761              2 years  Home Mortgage        54092.0  Debt Consolidation
# 60762            10+ years           Rent        56618.0  Debt Consolidation
# 60763              2 years       Own Home        25238.0               other
# 60765              4 years           Rent        37311.0  Debt Consolidation
# 60766              6 years           Rent        35434.0               other
# 60768              8 years  Home Mortgage        74176.0  Debt Consolidation
# 60769               1 year  Home Mortgage        74603.0  Debt Consolidation
# 60774              6 years           Rent        48960.0  Debt Consolidation
# 60776     less than 1 year       Own Home        69821.0       Business Loan
# 60778              2 years           Rent        64870.0               other
# 60779              6 years           Rent        55666.0  Debt Consolidation
# 60780              5 years           Rent        60078.0  Debt Consolidation
# 60781            10+ years  Home Mortgage        68873.0  Debt Consolidation
# 60782               1 year           Rent        43406.0  Debt Consolidation
# 60783              9 years  Home Mortgage        50757.0  Debt Consolidation
# 60784            10+ years  Home Mortgage        59742.0  Debt Consolidation
# 60787     less than 1 year  Home Mortgage        21534.0  Debt Consolidation
# 60788              4 years  Home Mortgage        39528.0  Debt Consolidation
# 60789            10+ years           Rent        66064.0  Debt Consolidation
# 60793            10+ years  Home Mortgage        76005.0   Home Improvements
# 60794              6 years           Rent       124875.0  Debt Consolidation
# 60795               1 year  Home Mortgage        50855.0  Debt Consolidation
# 60797            10+ years  Home Mortgage        99430.0  Debt Consolidation
# 60800              3 years           Rent        91143.0  Debt Consolidation
# 60803              8 years  Home Mortgage        42991.0  Debt Consolidation
#
#        Monthly.Debt  Years.of.Credit.History  Months.since.last.delinquent  \
# 0           1509.82                     34.4                           5.0
# 3           1358.11                     15.8                           NaN
# 4            339.93                     16.1                          47.0
# 5            504.90                     14.5                          70.0
# 6            296.87                     20.2                          51.0
# 7            354.83                      9.1                           NaN
# 8           1199.96                     12.5                          20.0
# 10           703.76                     14.9                           NaN
# 13           585.61                     13.4                           NaN
# 14          1044.33                     15.7                          56.0
# 15          1297.61                     15.0                          41.0
# 16          1353.07                     18.5                           NaN
# 17          1386.68                     16.6                          13.0
# 18          2078.88                     19.6                           NaN
# 19           890.73                     19.1                          23.0
# 20           622.04                     38.4                           NaN
# 22           472.57                      8.0                           NaN
# 23           281.93                     12.5                           NaN
# 24          1247.44                     14.0                           NaN
# 25           575.10                     10.8                          20.0
# 28           512.54                     10.0                          30.0
# 29           549.79                     19.4                           NaN
# 30           350.07                      9.2                           NaN
# 31          1095.28                     15.5                          16.0
# 32          1101.38                     23.0                          66.0
# 34           384.48                     22.5                           NaN
# 35          1681.69                     18.5                          74.0
# 36           226.87                     25.5                          40.0
# 37           775.71                     13.8                           NaN
# 39          1699.02                     21.6                           NaN
# ...             ...                      ...                           ...
# 60754        553.94                     21.8                           NaN
# 60755        785.74                     15.2                          78.0
# 60756       1088.30                     12.9                          13.0
# 60759       1434.90                     24.1                           6.0
# 60760        722.54                     16.7                           4.0
# 60761       1036.76                     12.5                           NaN
# 60762        693.57                     22.1                           NaN
# 60763        822.32                      6.0                           0.0
# 60765        306.57                     10.2                          38.0
# 60766        273.43                     29.0                          54.0
# 60768       1291.90                      8.8                           NaN
# 60769       1436.10                     12.5                           NaN
# 60774        999.60                     12.5                           NaN
# 60776        982.73                     19.5                          15.0
# 60778        262.73                      8.8                           NaN
# 60779        705.10                     15.6                          28.0
# 60780       1747.27                      8.8                           NaN
# 60781       1096.23                     16.8                           NaN
# 60782        799.39                     11.0                           NaN
# 60783       1171.64                     11.3                           NaN
# 60784        257.89                      7.5                           NaN
# 60787        270.96                     32.1                           NaN
# 60788        583.04                     14.6                          79.0
# 60789       1348.81                     21.0                           NaN
# 60793        560.54                     25.7                           NaN
# 60794        490.14                     10.0                           NaN
# 60795        834.87                     11.8                          58.0
# 60797       2419.46                     32.5                           NaN
# 60800        782.31                     18.0                          14.0
# 60803       1164.35                     23.0                          67.0
#
#        Number.of.Credit.Problems  Current.Credit.Balance  Maximum.Open.Credit  \
# 0                              0                   23986                40313
# 3                              1                   11782                25951
# 4                              0                   22909                25568
# 5                              1                    1837                 6269
# 6                              0                       0                    0
# 7                              0                    3646                 6840
# 8                              0                   17885                22583
# 10                             0                   20523                25369
# 13                             0                   22361                30341
# 14                             0                    4967                14395
# 15                             1                    7687                14559
# 16                             0                   18112                21690
# 17                             0                    7022                32659
# 18                             0                   19097                27127
# 19                             0                   16463                68882
# 20                             0                   18642                40971
# 22                             0                    4443                 7754
# 23                             1                    7209                26213
# 24                             0                   16270                40074
# 25                             0                    1414                11399
# 28                             0                    2530                 4487
# 29                             0                   11083                21562
# 30                             0                    3491                 7318
# 31                             0                    3831                 4988
# 32                             1                    6436                11514
# 34                             1                   12671                55820
# 35                             0                   22469                72482
# 36                             1                     283                 4791
# 37                             0                   33069                35292
# 39                             0                   34614                59169
# ...                          ...                     ...                  ...
# 60754                          0                   24832                35628
# 60755                          0                   16005                25404
# 60756                          0                    7868                13268
# 60759                          0                   32641                37092
# 60760                          0                   23962                42112
# 60761                          0                   11154                17932
# 60762                          0                    7326                 9769
# 60763                          0                     512                 2925
# 60765                          0                    4427                11293
# 60766                          0                    3584                 6788
# 60768                          0                   11512                12391
# 60769                          0                    8609                 8857
# 60774                          0                   15211                21823
# 60776                          0                    7815                15569
# 60778                          0                     105                 4217
# 60779                          0                    5214                 5577
# 60780                          0                    8771                20934
# 60781                          0                   37835                59582
# 60782                          0                   10407                11349
# 60783                          0                   20562                42308
# 60784                          0                   11804                24694
# 60787                          0                   11508                46780
# 60788                          0                   18859                22914
# 60789                          0                   32078                35962
# 60793                          0                   17500               119050
# 60794                          0                   14684                16937
# 60795                          0                    7671                12513
# 60797                          0                   34938                42868
# 60800                          0                    8328                51095
# 60803                          0                      39                 9724
#
#        Bankruptcies  Tax.Liens  Loan.Status Number.of.Open.Accounts.Buckets
# 0               0.0        0.0            1                      mais de 20
# 3               1.0        0.0            1                            0-10
# 4               0.0        0.0            1                            0-10
# 5               1.0        0.0            1                           11-20
# 6               0.0        0.0            0                            0-10
# 7               0.0        0.0            0                            0-10
# 8               0.0        0.0            1                            0-10
# 10              0.0        0.0            1                            0-10
# 13              0.0        0.0            1                           11-20
# 14              0.0        0.0            0                           11-20
# 15              0.0        0.0            1                           11-20
# 16              0.0        0.0            0                            0-10
# 17              0.0        0.0            1                           11-20
# 18              0.0        0.0            1                            0-10
# 19              0.0        0.0            1                           11-20
# 20              0.0        0.0            1                           11-20
# 22              0.0        0.0            1                            0-10
# 23              1.0        0.0            1                           11-20
# 24              0.0        0.0            1                           11-20
# 25              0.0        0.0            1                           11-20
# 28              0.0        0.0            1                            0-10
# 29              0.0        0.0            1                            0-10
# 30              0.0        0.0            0                            0-10
# 31              0.0        0.0            1                            0-10
# 32              1.0        0.0            1                           11-20
# 34              1.0        0.0            1                           11-20
# 35              0.0        0.0            0                           11-20
# 36              0.0        0.0            1                            0-10
# 37              0.0        0.0            1                           11-20
# 39              0.0        0.0            1                           11-20
# ...             ...        ...          ...                             ...
# 60754           0.0        0.0            1                            0-10
# 60755           0.0        0.0            1                           11-20
# 60756           0.0        0.0            1                           11-20
# 60759           0.0        0.0            1                           11-20
# 60760           0.0        0.0            0                            0-10
# 60761           0.0        0.0            1                           11-20
# 60762           0.0        0.0            1                            0-10
# 60763           0.0        0.0            0                            0-10
# 60765           0.0        0.0            1                           11-20
# 60766           0.0        0.0            1                            0-10
# 60768           0.0        0.0            1                            0-10
# 60769           0.0        0.0            1                           11-20
# 60774           0.0        0.0            1                           11-20
# 60776           0.0        0.0            1                           11-20
# 60778           0.0        0.0            1                            0-10
# 60779           0.0        0.0            0                            0-10
# 60780           0.0        0.0            0                           11-20
# 60781           0.0        0.0            1                           11-20
# 60782           0.0        0.0            0                           11-20
# 60783           0.0        0.0            0                           11-20
# 60784           0.0        0.0            1                           11-20
# 60787           0.0        0.0            1                           11-20
# 60788           0.0        0.0            1                           11-20
# 60789           0.0        0.0            0                           11-20
# 60793           0.0        0.0            1                            0-10
# 60794           0.0        0.0            1                           11-20
# 60795           0.0        0.0            1                           11-20
# 60797           0.0        0.0            1                      mais de 20
# 60800           0.0        0.0            0                           11-20
# 60803           0.0        0.0            1                            0-10
#
# [41178 rows x 18 columns]

# %%
#(2) Calculating current credit balance minus current loan amount
#if 'Credit.Minus.Loan'> 0, then, 1 (esta pedindo emprestimo menor do que tem de saldo disponivel, entao, ok); otherwise, 0

data['Credit.Minus.Loan'] = data['Current.Credit.Balance'] - data['Current.Loan.Amount']

def encoding_cml(x):
    if x > 0:
        return 1
    else:
        return 0

data['Credit.Minus.Loan'] = data['Credit.Minus.Loan'].apply(encoding_cml)

# %%
#(3) Number of Number.of.Credit.Problems: 0, 1 ou mais de 1
data['Number.of.Credit.Problems.Buckets'] = data['Number.of.Credit.Problems']

def encoding_nocp(x):
    if x ==0:
        return 0
    elif x ==1:
        return 1
    else:
        return 'mais de 1'

data['Number.of.Credit.Problems.Buckets'] = data['Number.of.Credit.Problems.Buckets'].apply(encoding_nocp)

# %%
# (4) Years.in.current.job - STRINGS CONVERTIDAS P/ INTEIROS DE 0 A 10 SENDO 'less than 1 year' E '10+ years' RESPECTIVAMENTE NO CAMPO NOVO 'yicj_enc', 

data['Years.in.current.job.enc'] = data['Years.in.current.job'].map({'less than 1 year': 0,
                                                             '1 year': 1,
                                                             '2 years': 2,
                                                             '3 years': 3,
                                                             '4 years': 4,
                                                             '5 years': 5,
                                                             '6 years': 6,
                                                             '7 years': 7,
                                                             '8 years': 8,
                                                             '9 years': 9,
                                                             '10+ years': 10})

# %%
# (5) Tipo de credito: a) Debt consolidation b) Home improvement c) Business loan d) Buy a car e) Medical bills f) Buy a house g) Others (juntar other + Other + o que sobrou, como moving, etc)

pur_cat_oth = ['other', 'moving', 'small_business', 'Take a Trip', 'major_purchase',
               'wedding', 'Educational Expenses', 'vacation', 'renewable_energy']

data['Purpose.Categories'] = data['Purpose']

for cat_oth in pur_cat_oth:
    data.loc[data['Purpose.Categories'] == cat_oth, 'Purpose.Categories'] = 'Other'

# %%
# (6) Tax.Liens 0 or 1:  TL==0 = 0 E TL>=1 = 1 NO CAMPO NOVO 'Tax.Liens.enc'

def encode_tl(x):
    if x == 0:
        x_enc = 0
    else:
        x_enc = 1
    return x_enc

data['Tax.Liens.enc'] = data['Tax.Liens'].map(encode_tl)

# %%
# (7) Criacao feature 'Leverage'

data['Leverage'] = (data['Monthly.Debt'] * 12) / data['Annual.Income']

# %%
# (8) Buckets para Credit.Score:
#Poor (579 and below)
#Below Average (580-619)
#Average (620-659)
#Good (660-719)
#Excellent (720 and above)

def encode_cs(x):
    if x >= 720:
        x_enc = 'Excellent'
    elif x >= 660:
        x_enc = 'Good'
    elif x >= 620:
        x_enc = 'Average'
    elif x >= 580:
        x_enc = 'Below Average'
    else:
        x_enc = 'Poor'
    return x_enc

data['Credit.Score.Buckets'] = data['Credit.Score'].map(encode_cs)

# %%
# (9) Years.of.Credit.History: criar 4 buckets (0-10; 10.01-20; 20.01-30; > 30.01)

data['Years.of.Credit.History.enc'] = pd.cut(x=data['Years.of.Credit.History'],
                              bins=[-1, 10, 20, 30, 100],
                              labels=['0 a 10', '10.1 a 20', '20.1 a 30', '30+'])

# %%
# (10) Bankruptcies: ja decretou falencia? Sim (> = 1) ou nao (0)

def encode_ban(x):
    if x == 0:
        x_enc = 0
    else:
        x_enc = 1
    return x_enc

data['Bankruptcies.enc'] = data['Bankruptcies'].map(encode_ban)

# %%
# (11) Months.since.last.delinquent: 
#Any delinquency in the past 3 yrs? Dividir meses por 12 --> se o resultado for menor que 3 (0 a 3), resultado eh sim e vira "1". Se for > 3 ou NA, vira "0".

data['Years.since.last.delinquent'] = data['Months.since.last.delinquent'] / 12
data.loc[data['Years.since.last.delinquent'].isnull(), 'Years.since.last.delinquent'] = 100

def encode_msld(x):
    if x <= 3:
        return 1
    else:
        return 0

data['Years.since.last.delinquent'] = data['Years.since.last.delinquent'].map(encode_msld)

# %%
# (12) Current loan amount / Annual income
data['Loan.vs.Income'] = data['Current.Loan.Amount'] / data['Annual.Income']

# %%
data.dtypes
# Out:
# Loan.ID                                 int64
# Current.Loan.Amount                     int64
# Term                                   object
# Credit.Score                          float64
# Years.in.current.job                   object
# Home.Ownership                         object
# Annual.Income                         float64
# Purpose                                object
# Monthly.Debt                          float64
# Years.of.Credit.History               float64
# Months.since.last.delinquent          float64
# Number.of.Open.Accounts                 int64
# Number.of.Credit.Problems               int64
# Current.Credit.Balance                  int64
# Maximum.Open.Credit                     int64
# Bankruptcies                          float64
# Tax.Liens                             float64
# Loan.Status                             int64
# Number.of.Open.Accounts.Buckets        object
# Credit.Minus.Loan                       int64
# Number.of.Credit.Problems.Buckets      object
# Years.in.current.job.enc                int64
# Purpose.Categories                     object
# Tax.Liens.enc                           int64
# Leverage                              float64
# Credit.Score.Buckets                   object
# Years.of.Credit.History.enc          category
# Bankruptcies.enc                        int64
# Years.since.last.delinquent             int64
# Loan.vs.Income                        float64
# dtype: object

# %% [markdown]
# ## Dataframe to be used in visualization (open another notebook) & transformers

# %%
#From data, dropped some columns to get the df to be used in next phase of workd
df = data.drop(columns=['Loan.ID', 'Credit.Score', 'Years.in.current.job',
                       'Purpose', 'Monthly.Debt', 'Years.of.Credit.History',
                       'Months.since.last.delinquent', 'Number.of.Open.Accounts',
                       'Number.of.Credit.Problems', 'Maximum.Open.Credit',
                       'Bankruptcies', 'Tax.Liens'])
df.head(5)
# Out:
#    Current.Loan.Amount        Term Home.Ownership  Annual.Income  \
# 0                17879  Short Term  Home Mortgage        95357.0
# 3                11200  Short Term           Rent        53965.0
# 4                 3608  Short Term  Home Mortgage        47709.0
# 5                 7877  Short Term  Home Mortgage        47707.0
# 6                 4732   Long Term           Rent        62721.0
#
#    Current.Credit.Balance  Loan.Status Number.of.Open.Accounts.Buckets  \
# 0                   23986            1                      mais de 20
# 3                   11782            1                            0-10
# 4                   22909            1                            0-10
# 5                    1837            1                           11-20
# 6                       0            0                            0-10
#
#    Credit.Minus.Loan Number.of.Credit.Problems.Buckets  \
# 0                  1                                 0
# 3                  1                                 1
# 4                  1                                 0
# 5                  0                                 1
# 6                  0                                 0
#
#    Years.in.current.job.enc  Purpose.Categories  Tax.Liens.enc  Leverage  \
# 0                         6  Debt Consolidation              0  0.190000
# 3                         4  Debt Consolidation              0  0.301998
# 4                        10   Home Improvements              0  0.085501
# 5                         5   Home Improvements              0  0.127000
# 6                        10               Other              0  0.056798
#
#   Credit.Score.Buckets Years.of.Credit.History.enc  Bankruptcies.enc  \
# 0            Excellent                         30+                 0
# 3            Excellent                   10.1 a 20                 1
# 4            Excellent                   10.1 a 20                 0
# 5            Excellent                   10.1 a 20                 1
# 6                 Good                   20.1 a 30                 0
#
#    Years.since.last.delinquent  Loan.vs.Income
# 0                            1        0.187495
# 3                            0        0.207542
# 4                            0        0.075625
# 5                            0        0.165112
# 6                            0        0.075445

# %%
df.isnull().sum()
# Out:
# Current.Loan.Amount                  0
# Term                                 0
# Home.Ownership                       0
# Annual.Income                        0
# Current.Credit.Balance               0
# Loan.Status                          0
# Number.of.Open.Accounts.Buckets      0
# Credit.Minus.Loan                    0
# Number.of.Credit.Problems.Buckets    0
# Years.in.current.job.enc             0
# Purpose.Categories                   0
# Tax.Liens.enc                        0
# Leverage                             0
# Credit.Score.Buckets                 0
# Years.of.Credit.History.enc          0
# Bankruptcies.enc                     0
# Years.since.last.delinquent          0
# Loan.vs.Income                       0
# dtype: int64

# %%
df.to_csv(r"C:\Users\m_day\code\mdayoub493\wanna_buy_house\notebooks\raw_data\data_cleaned_encoded.csv", index = False, header=True)
